# %%
from coupled_euler import *
import matplotlib.pyplot as plt
# %matplotlib widget

# %% [markdown]
# $$
# \begin{align*}
# \frac{d^2 x}{dt^2} = \frac{-k}{m}x \\
# \implies \frac{dx}{dt} = \frac{-k}{m}xt + C &\\
# C = \left. (x' - \frac{-k}{m}xt) \right|_{t=a} \\
# \implies x' = \frac{-k}{m}xt + \text{known constant}
# \end{align*}
# $$
#
# this is infact true for all equations,
# $$
# \frac{d^2 x}{dt^2} = f(x)
# $$
# and if $f(x)=mx+b $  then,
# $$
# \frac{dx}{dt} = f(x)t + x''(a)- f(x(a))a
# $$

# %%
## Simple Harmonic Oscillator
k,m = 1,1
a,xa,xxa = 0,1,0
simple_pendulum = set_problem(
    [ lambda t,x : -k/m*x*t + k/m*xa*a + xxa,],
    (0,7),(a,xa),1000,["t","x-alt"]
)
simple_pendulum2 = set_problem(
    [ lambda t,x,y : y , lambda t,x,y : -k/m*x ],
    (0,9),(a,xa,xxa),1000,["t","x"]
)
simple_pendulum.rk2()
simple_pendulum2.rk2()
fig,ax = plt.subplots(1,1,figsize=(10,8))
simple_pendulum.jt_plot(ax,1)
simple_pendulum2.jt_plot(ax,1)
plt.grid()
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
## Damped Harmonic Oscillator
k,m,b = 1,1,2
a,xa,xxa = 0,1,0
simple_pendulum = set_problem(
    [ lambda t,x : -k/m*x*t + k/m*xa*a +b/m + xxa,],
    (0,15),(a,xa),1000,["t","x-alt"]
)
simple_pendulum2 = set_problem(
    [ lambda t,x,y : y , lambda t,x,y : -k/m*x -b/m*y ],
    (0,9),(a,xa,xxa),1000,["t","x"]
)
simple_pendulum.rk2()
simple_pendulum2.rk2()
fig,ax = plt.subplots(1,1,figsize=(10,8))
simple_pendulum.jt_plot(ax,1)
simple_pendulum2.jt_plot(ax,1)
plt.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c1959d3c5c14> in <module>
#       2 k,m,b = 1,1,2
#       3 a,xa,xxa = 0,1,0
# ----> 4 simple_pendulum = set_problem(
#       5     [ lambda t,x : -k/m*x*t + k/m*xa*a +b/m + xxa,],
#       6     (0,15),(a,xa),1000,["t","x-alt"]
#
# NameError: name 'set_problem' is not defined

# %%
#Simple pendulum
g,L = 9.8,1
a,xa,xxa = 0,np.radians(120),0
simple_pendulum = set_problem(
    [ lambda t,x : -g/L*x*t + g/L*xa*a + xxa,],
    (0,1),(a,xa),1000,["t","x-alt"]
)
simple_pendulum2 = set_problem(
    [ lambda t,x,y : y , lambda t,x,y : -g/L*x ],
    (0,1),(a,xa,xxa),1000,["t","x"]
)
simple_pendulum.rk2()
simple_pendulum2.rk2()
np.degrees(simple_pendulum.dat["rk2"][:,0] )
np.degrees(simple_pendulum2.dat["rk2"][:,0]) 
fig,ax = plt.subplots(1,1,figsize=(10,8))
simple_pendulum.jt_plot(ax,1)
simple_pendulum2.jt_plot(ax,1)
plt.grid()
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Coupled pendulum
k,m = 1,1
a,x_a,x_b,y_a,y_b = 0,1,-1,0,0
w = 1
simple_pendulum = set_problem(
    [ lambda t,xa,xb,ya,yb : ya, lambda t,xa,xb,ya,yb : yb,
     lambda t,xa,xb,ya,yb : -(w**2 + k/m)*xa,  lambda t,xa,xb,ya,yb : -(w**2 + k/m)*xb],
    (0,7),(a,x_a,x_b,y_a,y_b),1000,["t","$x_a$","$x_b$","$x'_a$","$x'_b$"]
)
simple_pendulum.rk2()
fig,ax = plt.subplots(1,1,figsize=(10,8))
simple_pendulum.jt_plot(ax,1)
simple_pendulum.jt_plot(ax,2)
plt.grid()
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
